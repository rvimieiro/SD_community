# %%
import pandas as pd
import numpy as np
from time import sleep
import os.path

# %%
artigos = pd.read_csv("titulo_doc_comunidade.csv",delimiter=';',quotechar='\"')
artigos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 3 columns):
# title        571 non-null object
# community    571 non-null int64
# id           571 non-null object
# dtypes: int64(1), object(2)
# memory usage: 13.5+ KB

# %%
artigos.title.duplicated().sum()
# Out:
# 0

# %%
artigos['downloaded'] = artigos.id.apply(lambda x: os.path.isfile('pdf/{}.pdf'.format(x)))

# %%
artigos[~artigos.downloaded]
# Out:
#                                                  title  community  \
# 87   Seminormal forms and cyclotomic quiver Hecke a...          6
# 209  Proceedings of the Twenty-Seventh Conference o...        104
# 373  Proceedings of the 29th International Conferen...        151
#
#               id  downloaded
# 87   1304.0906v1       False
# 209  1205.2596v2       False
# 373  1207.4676v2       False

# %%
for ID in artigos[~artigos.downloaded].id.unique():
    link = "https://arxiv.org/pdf/"+ID+".pdf"
    ! cd pdf && curl -s -O {link} 
    sleep(np.random.random_sample()*35)

# %%
for ID in artigos.id.unique():
    pdf = "pdf/{}.pdf".format(ID)
    txt = "txt/{}.txt".format(ID)
    # !pdftotext {pdf} {txt}
# Out:
# Internal Error: xref num 164 not found but needed, try to reconstruct<0a>
# Internal Error: xref num 382 not found but needed, try to reconstruct<0a>
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (2): Illegal character <3f> in hex string
# Syntax Error (3): Illegal character <78> in hex string
# Syntax Error (4): Illegal character <6d> in hex string
# Syntax Error (5): Illegal character <6c> in hex string
# Syntax Error (7): Illegal character <76> in hex string
# Syntax Error (9): Illegal character <72> in hex string
# Syntax Error (10): Illegal character <73> in hex string
# Syntax Error (11): Illegal character <69> in hex string
# Syntax Error (12): Illegal character <6f> in hex string
# Syntax Error (13): Illegal character <6e> in hex string
# Syntax Error (14): Illegal character <3d> in hex string
# Syntax Error (15): Illegal character <22> in hex string
# Syntax Error (17): Illegal character <2e> in hex string
# Syntax Error (19): Illegal character <22> in hex string
# Syntax Error (22): Illegal character <6e> in hex string
# Syntax Error (24): Illegal character <6f> in hex string
# Syntax Error (26): Illegal character <69> in hex string
# Syntax Error (27): Illegal character <6e> in hex string
# Syntax Error (28): Illegal character <67> in hex string
# Syntax Error (29): Illegal character <3d> in hex string
# Syntax Error (30): Illegal character <22> in hex string
# Syntax Error (31): Illegal character <55> in hex string
# Syntax Error (32): Illegal character <54> in hex string
# Syntax Error (34): Illegal character <2d> in hex string
# Syntax Error (36): Illegal character <22> in hex string
# Syntax Error (37): Illegal character <3f> in hex string
# Syntax Error (41): Illegal character <21> in hex string
# Syntax Error (43): Illegal character <4f> in hex string
# Syntax Error (45): Illegal character <54> in hex string
# Syntax Error (46): Illegal character <59> in hex string
# Syntax Error (47): Illegal character <50> in hex string
# Syntax Error (50): Illegal character <68> in hex string
# Syntax Error (51): Illegal character <74> in hex string
# Syntax Error (52): Illegal character <6d> in hex string
# Syntax Error (53): Illegal character <6c> in hex string
# Syntax Error (55): Illegal character <50> in hex string
# Syntax Error (56): Illegal character <55> in hex string
# Syntax Error (58): Illegal character <4c> in hex string
# Syntax Error (59): Illegal character <49> in hex string
# Syntax Error (62): Illegal character <22> in hex string
# Syntax Error (63): Illegal character <2d> in hex string
# Syntax Error (64): Illegal character <2f> in hex string
# Syntax Error (65): Illegal character <2f> in hex string
# Syntax Error (66): Illegal character <57> in hex string
# Syntax Error (69): Illegal character <2f> in hex string
# Syntax Error (70): Illegal character <2f> in hex string
# Syntax Error (72): Illegal character <54> in hex string
# Syntax Error (75): Illegal character <58> in hex string
# Syntax Error (76): Illegal character <48> in hex string
# Syntax Error (77): Illegal character <54> in hex string
# Syntax Error (78): Illegal character <4d> in hex string
# Syntax Error (79): Illegal character <4c> in hex string
# Syntax Error (82): Illegal character <2e> in hex string
# Syntax Error (85): Illegal character <54> in hex string
# Syntax Error (86): Illegal character <72> in hex string
# Syntax Error (88): Illegal character <6e> in hex string
# Syntax Error (89): Illegal character <73> in hex string
# Syntax Error (90): Illegal character <69> in hex string
# Syntax Error (91): Illegal character <74> in hex string
# Syntax Error (92): Illegal character <69> in hex string
# Syntax Error (93): Illegal character <6f> in hex string
# Syntax Error (94): Illegal character <6e> in hex string
# Syntax Error (96): Illegal character <6c> in hex string
# Syntax Error (97): Illegal character <2f> in hex string
# Syntax Error (98): Illegal character <2f> in hex string
# Syntax Error (100): Illegal character <4e> in hex string
# Syntax Error (101): Illegal character <22> in hex string
# Syntax Error (103): Illegal character <22> in hex string
# Syntax Error (104): Illegal character <68> in hex string
# Syntax Error (105): Illegal character <74> in hex string
# Syntax Error (106): Illegal character <74> in hex string
# Syntax Error (107): Illegal character <70> in hex string
# Syntax Error (108): Illegal character <3a> in hex string
# Syntax Error (109): Illegal character <2f> in hex string
# Syntax Error (110): Illegal character <2f> in hex string
# Syntax Error (111): Illegal character <77> in hex string
# Syntax Error (112): Illegal character <77> in hex string
# Syntax Error (113): Illegal character <77> in hex string
# Syntax Error (114): Illegal character <2e> in hex string
# Syntax Error (115): Illegal character <77> in hex string
# Syntax Error (117): Illegal character <2e> in hex string
# Syntax Error (118): Illegal character <6f> in hex string
# Syntax Error (119): Illegal character <72> in hex string
# Syntax Error (120): Illegal character <67> in hex string
# Syntax Error (121): Illegal character <2f> in hex string
# Syntax Error (122): Illegal character <54> in hex string
# Syntax Error (123): Illegal character <52> in hex string
# Syntax Error (124): Illegal character <2f> in hex string
# Syntax Error (125): Illegal character <78> in hex string
# Syntax Error (126): Illegal character <68> in hex string
# Syntax Error (127): Illegal character <74> in hex string
# Syntax Error (128): Illegal character <6d> in hex string
# Syntax Error (129): Illegal character <6c> in hex string
# Syntax Error (131): Illegal character <2f> in hex string
# Syntax Error (133): Illegal character <54> in hex string
# Syntax Error (135): Illegal character <2f> in hex string
# Syntax Error (136): Illegal character <78> in hex string
# Syntax Error (137): Illegal character <68> in hex string
# Syntax Error (138): Illegal character <74> in hex string
# Syntax Error (139): Illegal character <6d> in hex string
# Syntax Error (140): Illegal character <6c> in hex string
# Syntax Error (142): Illegal character <2d> in hex string
# Syntax Error (143): Illegal character <74> in hex string
# Syntax Error (144): Illegal character <72> in hex string
# Syntax Error (146): Illegal character <6e> in hex string
# Syntax Error (147): Illegal character <73> in hex string
# Syntax Error (148): Illegal character <69> in hex string
# Syntax Error (149): Illegal character <74> in hex string
# Syntax Error (150): Illegal character <69> in hex string
# Syntax Error (151): Illegal character <6f> in hex string
# Syntax Error (152): Illegal character <6e> in hex string
# Syntax Error (154): Illegal character <6c> in hex string
# Syntax Error (155): Illegal character <2e> in hex string
# Syntax Error (157): Illegal character <74> in hex string
# Syntax Error (159): Illegal character <22> in hex string
# Syntax Error (163): Illegal character <68> in hex string
# Syntax Error (164): Illegal character <74> in hex string
# Syntax Error (165): Illegal character <6d> in hex string
# Syntax Error (166): Illegal character <6c> in hex string
# Syntax Error (168): Illegal character <78> in hex string
# Syntax Error (169): Illegal character <6d> in hex string
# Syntax Error (170): Illegal character <6c> in hex string
# Syntax Error (171): Illegal character <6e> in hex string
# Syntax Error (172): Illegal character <73> in hex string
# Syntax Error (173): Illegal character <3d> in hex string
# Syntax Error (174): Illegal character <22> in hex string
# Syntax Error (175): Illegal character <68> in hex string
# Syntax Error (176): Illegal character <74> in hex string
# Syntax Error (177): Illegal character <74> in hex string
# Syntax Error (178): Illegal character <70> in hex string
# Syntax Error (179): Illegal character <3a> in hex string
# Syntax Error (180): Illegal character <2f> in hex string
# Syntax Error (181): Illegal character <2f> in hex string
# Syntax Error (182): Illegal character <77> in hex string
# Syntax Error (183): Illegal character <77> in hex string
# Syntax Error (184): Illegal character <77> in hex string
# Syntax Error (185): Illegal character <2e> in hex string
# Syntax Error (186): Illegal character <77> in hex string
# Syntax Error (188): Illegal character <2e> in hex string
# Syntax Error (189): Illegal character <6f> in hex string
# Syntax Error (190): Illegal character <72> in hex string
# Syntax Error (191): Illegal character <67> in hex string
# Syntax Error (192): Illegal character <2f> in hex string
# Syntax Error (197): Illegal character <2f> in hex string
# Syntax Error (198): Illegal character <78> in hex string
# Syntax Error (199): Illegal character <68> in hex string
# Syntax Error (200): Illegal character <74> in hex string
# Syntax Error (201): Illegal character <6d> in hex string
# Syntax Error (202): Illegal character <6c> in hex string
# Syntax Error (203): Illegal character <22> in hex string
# Syntax Error (205): Illegal character <6c> in hex string
# Syntax Error (207): Illegal character <6e> in hex string
# Syntax Error (208): Illegal character <67> in hex string
# Syntax Error (209): Illegal character <3d> in hex string
# Syntax Error (210): Illegal character <22> in hex string
# Syntax Error (212): Illegal character <6e> in hex string
# Syntax Error (213): Illegal character <22> in hex string
# Syntax Error (217): Illegal character <68> in hex string
# Syntax Error (224): Illegal character <74> in hex string
# Syntax Error (225): Illegal character <69> in hex string
# Syntax Error (226): Illegal character <74> in hex string
# Syntax Error (227): Illegal character <6c> in hex string
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (2): Illegal character <3f> in hex string
# Syntax Error (3): Illegal character <78> in hex string
# Syntax Error (4): Illegal character <6d> in hex string
# Syntax Error (5): Illegal character <6c> in hex string
# Syntax Error (7): Illegal character <76> in hex string
# Syntax Error (9): Illegal character <72> in hex string
# Syntax Error (10): Illegal character <73> in hex string
# Syntax Error (11): Illegal character <69> in hex string
# Syntax Error (12): Illegal character <6f> in hex string
# Syntax Error (13): Illegal character <6e> in hex string
# Syntax Error (14): Illegal character <3d> in hex string
# Syntax Error (15): Illegal character <22> in hex string
# Syntax Error (17): Illegal character <2e> in hex string
# Syntax Error (19): Illegal character <22> in hex string
# Syntax Error (22): Illegal character <6e> in hex string
# Syntax Error (24): Illegal character <6f> in hex string
# Syntax Error (26): Illegal character <69> in hex string
# Syntax Error (27): Illegal character <6e> in hex string
# Syntax Error (28): Illegal character <67> in hex string
# Syntax Error (29): Illegal character <3d> in hex string
# Syntax Error (30): Illegal character <22> in hex string
# Syntax Error (31): Illegal character <55> in hex string
# Syntax Error (32): Illegal character <54> in hex string
# Syntax Error (34): Illegal character <2d> in hex string
# Syntax Error (36): Illegal character <22> in hex string
# Syntax Error (37): Illegal character <3f> in hex string
# Syntax Error (41): Illegal character <21> in hex string
# Syntax Error (43): Illegal character <4f> in hex string
# Syntax Error (45): Illegal character <54> in hex string
# Syntax Error (46): Illegal character <59> in hex string
# Syntax Error (47): Illegal character <50> in hex string
# Syntax Error (50): Illegal character <68> in hex string
# Syntax Error (51): Illegal character <74> in hex string
# Syntax Error (52): Illegal character <6d> in hex string
# Syntax Error (53): Illegal character <6c> in hex string
# Syntax Error (55): Illegal character <50> in hex string
# Syntax Error (56): Illegal character <55> in hex string
# Syntax Error (58): Illegal character <4c> in hex string
# Syntax Error (59): Illegal character <49> in hex string
# Syntax Error (62): Illegal character <22> in hex string
# Syntax Error (63): Illegal character <2d> in hex string
# Syntax Error (64): Illegal character <2f> in hex string
# Syntax Error (65): Illegal character <2f> in hex string
# Syntax Error (66): Illegal character <57> in hex string
# Syntax Error (69): Illegal character <2f> in hex string
# Syntax Error (70): Illegal character <2f> in hex string
# Syntax Error (72): Illegal character <54> in hex string
# Syntax Error (75): Illegal character <58> in hex string
# Syntax Error (76): Illegal character <48> in hex string
# Syntax Error (77): Illegal character <54> in hex string
# Syntax Error (78): Illegal character <4d> in hex string
# Syntax Error (79): Illegal character <4c> in hex string
# Syntax Error (82): Illegal character <2e> in hex string
# Syntax Error (85): Illegal character <54> in hex string
# Syntax Error (86): Illegal character <72> in hex string
# Syntax Error (88): Illegal character <6e> in hex string
# Syntax Error (89): Illegal character <73> in hex string
# Syntax Error (90): Illegal character <69> in hex string
# Syntax Error (91): Illegal character <74> in hex string
# Syntax Error (92): Illegal character <69> in hex string
# Syntax Error (93): Illegal character <6f> in hex string
# Syntax Error (94): Illegal character <6e> in hex string
# Syntax Error (96): Illegal character <6c> in hex string
# Syntax Error (97): Illegal character <2f> in hex string
# Syntax Error (98): Illegal character <2f> in hex string
# Syntax Error (100): Illegal character <4e> in hex string
# Syntax Error (101): Illegal character <22> in hex string
# Syntax Error (103): Illegal character <22> in hex string
# Syntax Error (104): Illegal character <68> in hex string
# Syntax Error (105): Illegal character <74> in hex string
# Syntax Error (106): Illegal character <74> in hex string
# Syntax Error (107): Illegal character <70> in hex string
# Syntax Error (108): Illegal character <3a> in hex string
# Syntax Error (109): Illegal character <2f> in hex string
# Syntax Error (110): Illegal character <2f> in hex string
# Syntax Error (111): Illegal character <77> in hex string
# Syntax Error (112): Illegal character <77> in hex string
# Syntax Error (113): Illegal character <77> in hex string
# Syntax Error (114): Illegal character <2e> in hex string
# Syntax Error (115): Illegal character <77> in hex string
# Syntax Error (117): Illegal character <2e> in hex string
# Syntax Error (118): Illegal character <6f> in hex string
# Syntax Error (119): Illegal character <72> in hex string
# Syntax Error (120): Illegal character <67> in hex string
# Syntax Error (121): Illegal character <2f> in hex string
# Syntax Error (122): Illegal character <54> in hex string
# Syntax Error (123): Illegal character <52> in hex string
# Syntax Error (124): Illegal character <2f> in hex string
# Syntax Error (125): Illegal character <78> in hex string
# Syntax Error (126): Illegal character <68> in hex string
# Syntax Error (127): Illegal character <74> in hex string
# Syntax Error (128): Illegal character <6d> in hex string
# Syntax Error (129): Illegal character <6c> in hex string
# Syntax Error (131): Illegal character <2f> in hex string
# Syntax Error (133): Illegal character <54> in hex string
# Syntax Error (135): Illegal character <2f> in hex string
# Syntax Error (136): Illegal character <78> in hex string
# Syntax Error (137): Illegal character <68> in hex string
# Syntax Error (138): Illegal character <74> in hex string
# Syntax Error (139): Illegal character <6d> in hex string
# Syntax Error (140): Illegal character <6c> in hex string
# Syntax Error (142): Illegal character <2d> in hex string
# Syntax Error (143): Illegal character <74> in hex string
# Syntax Error (144): Illegal character <72> in hex string
# Syntax Error (146): Illegal character <6e> in hex string
# Syntax Error (147): Illegal character <73> in hex string
# Syntax Error (148): Illegal character <69> in hex string
# Syntax Error (149): Illegal character <74> in hex string
# Syntax Error (150): Illegal character <69> in hex string
# Syntax Error (151): Illegal character <6f> in hex string
# Syntax Error (152): Illegal character <6e> in hex string
# Syntax Error (154): Illegal character <6c> in hex string
# Syntax Error (155): Illegal character <2e> in hex string
# Syntax Error (157): Illegal character <74> in hex string
# Syntax Error (159): Illegal character <22> in hex string
# Syntax Error (163): Illegal character <68> in hex string
# Syntax Error (164): Illegal character <74> in hex string
# Syntax Error (165): Illegal character <6d> in hex string
# Syntax Error (166): Illegal character <6c> in hex string
# Syntax Error (168): Illegal character <78> in hex string
# Syntax Error (169): Illegal character <6d> in hex string
# Syntax Error (170): Illegal character <6c> in hex string
# Syntax Error (171): Illegal character <6e> in hex string
# Syntax Error (172): Illegal character <73> in hex string
# Syntax Error (173): Illegal character <3d> in hex string
# Syntax Error (174): Illegal character <22> in hex string
# Syntax Error (175): Illegal character <68> in hex string
# Syntax Error (176): Illegal character <74> in hex string
# Syntax Error (177): Illegal character <74> in hex string
# Syntax Error (178): Illegal character <70> in hex string
# Syntax Error (179): Illegal character <3a> in hex string
# Syntax Error (180): Illegal character <2f> in hex string
# Syntax Error (181): Illegal character <2f> in hex string
# Syntax Error (182): Illegal character <77> in hex string
# Syntax Error (183): Illegal character <77> in hex string
# Syntax Error (184): Illegal character <77> in hex string
# Syntax Error (185): Illegal character <2e> in hex string
# Syntax Error (186): Illegal character <77> in hex string
# Syntax Error (188): Illegal character <2e> in hex string
# Syntax Error (189): Illegal character <6f> in hex string
# Syntax Error (190): Illegal character <72> in hex string
# Syntax Error (191): Illegal character <67> in hex string
# Syntax Error (192): Illegal character <2f> in hex string
# Syntax Error (197): Illegal character <2f> in hex string
# Syntax Error (198): Illegal character <78> in hex string
# Syntax Error (199): Illegal character <68> in hex string
# Syntax Error (200): Illegal character <74> in hex string
# Syntax Error (201): Illegal character <6d> in hex string
# Syntax Error (202): Illegal character <6c> in hex string
# Syntax Error (203): Illegal character <22> in hex string
# Syntax Error (205): Illegal character <6c> in hex string
# Syntax Error (207): Illegal character <6e> in hex string
# Syntax Error (208): Illegal character <67> in hex string
# Syntax Error (209): Illegal character <3d> in hex string
# Syntax Error (210): Illegal character <22> in hex string
# Syntax Error (212): Illegal character <6e> in hex string
# Syntax Error (213): Illegal character <22> in hex string
# Syntax Error (217): Illegal character <68> in hex string
# Syntax Error (224): Illegal character <74> in hex string
# Syntax Error (225): Illegal character <69> in hex string
# Syntax Error (226): Illegal character <74> in hex string
# Syntax Error (227): Illegal character <6c> in hex string
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
# Syntax Error: Expected the default config, but wasn't able to find it, or it isn't a Dictionary
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (2): Illegal character <3f> in hex string
# Syntax Error (3): Illegal character <78> in hex string
# Syntax Error (4): Illegal character <6d> in hex string
# Syntax Error (5): Illegal character <6c> in hex string
# Syntax Error (7): Illegal character <76> in hex string
# Syntax Error (9): Illegal character <72> in hex string
# Syntax Error (10): Illegal character <73> in hex string
# Syntax Error (11): Illegal character <69> in hex string
# Syntax Error (12): Illegal character <6f> in hex string
# Syntax Error (13): Illegal character <6e> in hex string
# Syntax Error (14): Illegal character <3d> in hex string
# Syntax Error (15): Illegal character <22> in hex string
# Syntax Error (17): Illegal character <2e> in hex string
# Syntax Error (19): Illegal character <22> in hex string
# Syntax Error (22): Illegal character <6e> in hex string
# Syntax Error (24): Illegal character <6f> in hex string
# Syntax Error (26): Illegal character <69> in hex string
# Syntax Error (27): Illegal character <6e> in hex string
# Syntax Error (28): Illegal character <67> in hex string
# Syntax Error (29): Illegal character <3d> in hex string
# Syntax Error (30): Illegal character <22> in hex string
# Syntax Error (31): Illegal character <55> in hex string
# Syntax Error (32): Illegal character <54> in hex string
# Syntax Error (34): Illegal character <2d> in hex string
# Syntax Error (36): Illegal character <22> in hex string
# Syntax Error (37): Illegal character <3f> in hex string
# Syntax Error (41): Illegal character <21> in hex string
# Syntax Error (43): Illegal character <4f> in hex string
# Syntax Error (45): Illegal character <54> in hex string
# Syntax Error (46): Illegal character <59> in hex string
# Syntax Error (47): Illegal character <50> in hex string
# Syntax Error (50): Illegal character <68> in hex string
# Syntax Error (51): Illegal character <74> in hex string
# Syntax Error (52): Illegal character <6d> in hex string
# Syntax Error (53): Illegal character <6c> in hex string
# Syntax Error (55): Illegal character <50> in hex string
# Syntax Error (56): Illegal character <55> in hex string
# Syntax Error (58): Illegal character <4c> in hex string
# Syntax Error (59): Illegal character <49> in hex string
# Syntax Error (62): Illegal character <22> in hex string
# Syntax Error (63): Illegal character <2d> in hex string
# Syntax Error (64): Illegal character <2f> in hex string
# Syntax Error (65): Illegal character <2f> in hex string
# Syntax Error (66): Illegal character <57> in hex string
# Syntax Error (69): Illegal character <2f> in hex string
# Syntax Error (70): Illegal character <2f> in hex string
# Syntax Error (72): Illegal character <54> in hex string
# Syntax Error (75): Illegal character <58> in hex string
# Syntax Error (76): Illegal character <48> in hex string
# Syntax Error (77): Illegal character <54> in hex string
# Syntax Error (78): Illegal character <4d> in hex string
# Syntax Error (79): Illegal character <4c> in hex string
# Syntax Error (82): Illegal character <2e> in hex string
# Syntax Error (85): Illegal character <54> in hex string
# Syntax Error (86): Illegal character <72> in hex string
# Syntax Error (88): Illegal character <6e> in hex string
# Syntax Error (89): Illegal character <73> in hex string
# Syntax Error (90): Illegal character <69> in hex string
# Syntax Error (91): Illegal character <74> in hex string
# Syntax Error (92): Illegal character <69> in hex string
# Syntax Error (93): Illegal character <6f> in hex string
# Syntax Error (94): Illegal character <6e> in hex string
# Syntax Error (96): Illegal character <6c> in hex string
# Syntax Error (97): Illegal character <2f> in hex string
# Syntax Error (98): Illegal character <2f> in hex string
# Syntax Error (100): Illegal character <4e> in hex string
# Syntax Error (101): Illegal character <22> in hex string
# Syntax Error (103): Illegal character <22> in hex string
# Syntax Error (104): Illegal character <68> in hex string
# Syntax Error (105): Illegal character <74> in hex string
# Syntax Error (106): Illegal character <74> in hex string
# Syntax Error (107): Illegal character <70> in hex string
# Syntax Error (108): Illegal character <3a> in hex string
# Syntax Error (109): Illegal character <2f> in hex string
# Syntax Error (110): Illegal character <2f> in hex string
# Syntax Error (111): Illegal character <77> in hex string
# Syntax Error (112): Illegal character <77> in hex string
# Syntax Error (113): Illegal character <77> in hex string
# Syntax Error (114): Illegal character <2e> in hex string
# Syntax Error (115): Illegal character <77> in hex string
# Syntax Error (117): Illegal character <2e> in hex string
# Syntax Error (118): Illegal character <6f> in hex string
# Syntax Error (119): Illegal character <72> in hex string
# Syntax Error (120): Illegal character <67> in hex string
# Syntax Error (121): Illegal character <2f> in hex string
# Syntax Error (122): Illegal character <54> in hex string
# Syntax Error (123): Illegal character <52> in hex string
# Syntax Error (124): Illegal character <2f> in hex string
# Syntax Error (125): Illegal character <78> in hex string
# Syntax Error (126): Illegal character <68> in hex string
# Syntax Error (127): Illegal character <74> in hex string
# Syntax Error (128): Illegal character <6d> in hex string
# Syntax Error (129): Illegal character <6c> in hex string
# Syntax Error (131): Illegal character <2f> in hex string
# Syntax Error (133): Illegal character <54> in hex string
# Syntax Error (135): Illegal character <2f> in hex string
# Syntax Error (136): Illegal character <78> in hex string
# Syntax Error (137): Illegal character <68> in hex string
# Syntax Error (138): Illegal character <74> in hex string
# Syntax Error (139): Illegal character <6d> in hex string
# Syntax Error (140): Illegal character <6c> in hex string
# Syntax Error (142): Illegal character <2d> in hex string
# Syntax Error (143): Illegal character <74> in hex string
# Syntax Error (144): Illegal character <72> in hex string
# Syntax Error (146): Illegal character <6e> in hex string
# Syntax Error (147): Illegal character <73> in hex string
# Syntax Error (148): Illegal character <69> in hex string
# Syntax Error (149): Illegal character <74> in hex string
# Syntax Error (150): Illegal character <69> in hex string
# Syntax Error (151): Illegal character <6f> in hex string
# Syntax Error (152): Illegal character <6e> in hex string
# Syntax Error (154): Illegal character <6c> in hex string
# Syntax Error (155): Illegal character <2e> in hex string
# Syntax Error (157): Illegal character <74> in hex string
# Syntax Error (159): Illegal character <22> in hex string
# Syntax Error (163): Illegal character <68> in hex string
# Syntax Error (164): Illegal character <74> in hex string
# Syntax Error (165): Illegal character <6d> in hex string
# Syntax Error (166): Illegal character <6c> in hex string
# Syntax Error (168): Illegal character <78> in hex string
# Syntax Error (169): Illegal character <6d> in hex string
# Syntax Error (170): Illegal character <6c> in hex string
# Syntax Error (171): Illegal character <6e> in hex string
# Syntax Error (172): Illegal character <73> in hex string
# Syntax Error (173): Illegal character <3d> in hex string
# Syntax Error (174): Illegal character <22> in hex string
# Syntax Error (175): Illegal character <68> in hex string
# Syntax Error (176): Illegal character <74> in hex string
# Syntax Error (177): Illegal character <74> in hex string
# Syntax Error (178): Illegal character <70> in hex string
# Syntax Error (179): Illegal character <3a> in hex string
# Syntax Error (180): Illegal character <2f> in hex string
# Syntax Error (181): Illegal character <2f> in hex string
# Syntax Error (182): Illegal character <77> in hex string
# Syntax Error (183): Illegal character <77> in hex string
# Syntax Error (184): Illegal character <77> in hex string
# Syntax Error (185): Illegal character <2e> in hex string
# Syntax Error (186): Illegal character <77> in hex string
# Syntax Error (188): Illegal character <2e> in hex string
# Syntax Error (189): Illegal character <6f> in hex string
# Syntax Error (190): Illegal character <72> in hex string
# Syntax Error (191): Illegal character <67> in hex string
# Syntax Error (192): Illegal character <2f> in hex string
# Syntax Error (197): Illegal character <2f> in hex string
# Syntax Error (198): Illegal character <78> in hex string
# Syntax Error (199): Illegal character <68> in hex string
# Syntax Error (200): Illegal character <74> in hex string
# Syntax Error (201): Illegal character <6d> in hex string
# Syntax Error (202): Illegal character <6c> in hex string
# Syntax Error (203): Illegal character <22> in hex string
# Syntax Error (205): Illegal character <6c> in hex string
# Syntax Error (207): Illegal character <6e> in hex string
# Syntax Error (208): Illegal character <67> in hex string
# Syntax Error (209): Illegal character <3d> in hex string
# Syntax Error (210): Illegal character <22> in hex string
# Syntax Error (212): Illegal character <6e> in hex string
# Syntax Error (213): Illegal character <22> in hex string
# Syntax Error (217): Illegal character <68> in hex string
# Syntax Error (224): Illegal character <74> in hex string
# Syntax Error (225): Illegal character <69> in hex string
# Syntax Error (226): Illegal character <74> in hex string
# Syntax Error (227): Illegal character <6c> in hex string
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table

# %% [markdown]
# O código a seguir foi adaptado de http://brandonrose.org/clustering#Stopwords,-stemming,-and-tokenizing

# %%
import nltk
from nltk.stem.snowball import SnowballStemmer
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
import re

# %%
nltk.download('stopwords')
nltk.download('punkt')
stopwords = nltk.corpus.stopwords.words('english')
stemmer = SnowballStemmer("english")
def tokenize_and_stem(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(re.sub('[-\xad][\s\n]','',text)) \
                          for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]{3,}', token):
            filtered_tokens.append(token)
    #stems = [stemmer.stem(t) for t in filtered_tokens]
    #return stems
    return filtered_tokens
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/rvimieiro/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/rvimieiro/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
tfidf_vectorizer = TfidfVectorizer(input='filename',max_df=0.9, max_features=20000,
                                 min_df=0.05, stop_words='english',
                                 use_idf=True, tokenizer=tokenize_and_stem, ngram_range=(1,3))
t = !ls txt2/*.txt
# %time tfidf_matrix = tfidf_vectorizer.fit_transform(t)

print(tfidf_matrix.shape)
# Out:
# CPU times: user 1min 24s, sys: 1.53 s, total: 1min 25s
# Wall time: 1min 29s
# (568, 4407)

# %%
terms = tfidf_vectorizer.get_feature_names()
terms[:10]
# Out:
# ['aaai',
#  'aaai press',
#  'aalborg',
#  'ability',
#  'able',
#  'ables',
#  'absence',
#  'absent',
#  'absolute',
#  'abstract']

# %%
with open('terms.txt','w') as f:
    f.write('\n'.join(terms))

# %%
x = tfidf_matrix.toarray()

# %%
df = pd.DataFrame(x,columns=terms,index=[re.sub('txt2?/(\d+.?\d+v\d+)\.txt','\\1',a) for a in t])
df.head()
# Out:
#                  aaai  aaai press  aalborg   ability      able     ables  \
# 1201.2250v1  0.000000         0.0      0.0  0.000000  0.000000  0.000000
# 1201.2706v2  0.000000         0.0      0.0  0.000000  0.009938  0.000000
# 1201.6655v1  0.000000         0.0      0.0  0.000000  0.000000  0.000000
# 1202.1334v2  0.000000         0.0      0.0  0.008395  0.005955  0.000000
# 1202.3698v1  0.025457         0.0      0.0  0.000000  0.000000  0.010693
#
#               absence  absent  absolute  abstract    ...     y-axis  years  \
# 1201.2250v1  0.010583     0.0  0.000000       0.0    ...        0.0    0.0
# 1201.2706v2  0.000000     0.0  0.000000       0.0    ...        0.0    0.0
# 1201.6655v1  0.000000     0.0  0.021812       0.0    ...        0.0    0.0
# 1202.1334v2  0.000000     0.0  0.000000       0.0    ...        0.0    0.0
# 1202.3698v1  0.000000     0.0  0.000000       0.0    ...        0.0    0.0
#
#              yes     yield  yielding    yields      york      zero  zeros  \
# 1201.2250v1  0.0  0.000000  0.000000  0.000000  0.024284  0.012901    0.0
# 1201.2706v2  0.0  0.000000  0.000000  0.000000  0.013044  0.000000    0.0
# 1201.6655v1  0.0  0.000000  0.010950  0.000000  0.000000  0.000000    0.0
# 1202.1334v2  0.0  0.016297  0.010620  0.000000  0.000000  0.000000    0.0
# 1202.3698v1  0.0  0.023953  0.007805  0.005548  0.000000  0.000000    0.0
#
#                 zhang
# 1201.2250v1  0.000000
# 1201.2706v2  0.000000
# 1201.6655v1  0.000000
# 1202.1334v2  0.010219
# 1202.3698v1  0.000000
#
# [5 rows x 4407 columns]

# %%
doc_term_matrix = pd.merge(df,artigos[['community','id']],left_index=True,right_on='id')
doc_term_matrix.reset_index(inplace=True)
doc_term_matrix.drop('level_0',inplace=True,axis=1)
doc_term_matrix.head()
# Out:
#        aaai  aaai press  aalborg   ability      able     ables   absence  \
# 0  0.000000         0.0      0.0  0.000000  0.000000  0.000000  0.010583
# 1  0.000000         0.0      0.0  0.000000  0.009938  0.000000  0.000000
# 2  0.000000         0.0      0.0  0.000000  0.000000  0.000000  0.000000
# 3  0.000000         0.0      0.0  0.008395  0.005955  0.000000  0.000000
# 4  0.025457         0.0      0.0  0.000000  0.000000  0.010693  0.000000
#
#    absent  absolute  abstract     ...       yes     yield  yielding    yields  \
# 0     0.0  0.000000       0.0     ...       0.0  0.000000  0.000000  0.000000
# 1     0.0  0.000000       0.0     ...       0.0  0.000000  0.000000  0.000000
# 2     0.0  0.021812       0.0     ...       0.0  0.000000  0.010950  0.000000
# 3     0.0  0.000000       0.0     ...       0.0  0.016297  0.010620  0.000000
# 4     0.0  0.000000       0.0     ...       0.0  0.023953  0.007805  0.005548
#
#        york      zero  zeros     zhang  community_y           id
# 0  0.024284  0.012901    0.0  0.000000            6  1201.2250v1
# 1  0.013044  0.000000    0.0  0.000000          116  1201.2706v2
# 2  0.000000  0.000000    0.0  0.000000          151  1201.6655v1
# 3  0.000000  0.000000    0.0  0.010219          151  1202.1334v2
# 4  0.000000  0.000000    0.0  0.000000          134  1202.3698v1
#
# [5 rows x 4409 columns]

# %%
doc_term_matrix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568 entries, 0 to 567
# Columns: 4265 entries, aaai to id
# dtypes: float64(4263), int64(1), object(1)
# memory usage: 18.5+ MB

# %%
doc_term_matrix.community.unique()
# Out:
# array([  6, 116, 151, 134, 104,  80, 153, 145, 156, 256])

# %%
x2 = doc_term_matrix.drop(['id','community_y'],axis=1).\
                            replace(to_replace=0,value=np.NaN).\
                            apply(lambda a: pd.qcut(a,3,labels=['baixo','medio','alto']))
x2 = x2.apply(lambda a: a.cat.add_categories(['zero']))
x2['community_y'] = doc_term_matrix.community_y
x2.head()
# Out:
#    aaai aaai press aalborg ability   able  ables absence absent absolute  \
# 0   NaN        NaN     NaN     NaN    NaN    NaN   medio    NaN      NaN
# 1   NaN        NaN     NaN     NaN   alto    NaN     NaN    NaN      NaN
# 2   NaN        NaN     NaN     NaN    NaN    NaN     NaN    NaN     alto
# 3   NaN        NaN     NaN   medio  medio    NaN     NaN    NaN      NaN
# 4  alto        NaN     NaN     NaN    NaN  medio     NaN    NaN      NaN
#
#   abstract     ...     years  yes yield yielding yields  york   zero zeros  \
# 0      NaN     ...       NaN  NaN   NaN      NaN    NaN  alto  medio   NaN
# 1      NaN     ...       NaN  NaN   NaN      NaN    NaN  alto    NaN   NaN
# 2      NaN     ...       NaN  NaN   NaN    medio    NaN   NaN    NaN   NaN
# 3      NaN     ...       NaN  NaN  alto    medio    NaN   NaN    NaN   NaN
# 4      NaN     ...       NaN  NaN  alto    baixo  baixo   NaN    NaN   NaN
#
#    zhang community_y
# 0    NaN           6
# 1    NaN         116
# 2    NaN         151
# 3  medio         151
# 4    NaN         134
#
# [5 rows x 4408 columns]

# %%
x2.fillna('zero').to_csv('doc_term_matrix_tfidf_wo_header_nostem_discrete.csv',header=True,index=False)

# %%
freq_vectorizer = CountVectorizer(input='filename',max_df=0.9, max_features=20000,
                                 min_df=0.05, stop_words='english',
                                 tokenizer=tokenize_and_stem, ngram_range=(1,3))
t = !ls txt2/*.txt
# %time freq_matrix = freq_vectorizer.fit_transform(t)

print(freq_matrix.shape)
# Out:
# CPU times: user 1min 35s, sys: 2.5 s, total: 1min 38s
# Wall time: 1min 44s
# (568, 4407)

# %%
terms_freq = freq_vectorizer.get_feature_names()
#with open('terms_tf.txt','w') as f:
#    f.write('\n'.join(terms_freq))

# %%
x = freq_matrix.toarray()
df = pd.DataFrame(x,columns=terms_freq,index=[re.sub('txt2?/(\d+.?\d+v\d+)\.txt','\\1',a) for a in t])
doc_term_matrix = pd.merge(df,artigos[['community','id']],left_index=True,right_on='id')
doc_term_matrix.set_index('id',inplace=True)
#doc_term_matrix.head()

# %%
doc_term_matrix.to_csv('doc_term_matrix_freq.csv',header=True)

# %%
filtro = doc_term_matrix.drop('community_y',axis=1)\
                .replace(to_replace=0,value=np.NaN)\
                .apply(lambda a: [-1,0,a.quantile(.75),a.max()])

# %%
np.sum(filtro.apply(lambda a: len(np.unique(a))) == 4)
# Out:
# 4350

# %%
x2 = doc_term_matrix.drop(['community_y'],axis=1)\
            .loc[:,filtro.apply(lambda a: len(np.unique(a))) == 4]\
            .apply(lambda a: pd.cut(a,
                                    [-1,0,a.replace(to_replace=0,value=np.NaN).quantile(.75),a.max()],
                                    labels=['zero','baixo','alto']))
#x2 = x2.apply(lambda a: a.cat.add_categories(['zero']))
x2['community_y'] = doc_term_matrix.community_y
x2.head()
# Out:
#              aaai aaai press aalborg ability   able  ables absence absent  \
# id
# 1201.2250v1  zero       zero    zero    zero   zero   zero   baixo   zero
# 1201.2706v2  zero       zero    zero    zero  baixo   zero    zero   zero
# 1201.6655v1  zero       zero    zero    zero   zero   zero    zero   zero
# 1202.1334v2  zero       zero    zero   baixo  baixo   zero    zero   zero
# 1202.3698v1  alto       zero    zero    zero   zero  baixo    zero   zero
#
#             absolute abstract     ...     years   yes  yield yielding yields  \
# id                                ...
# 1201.2250v1     zero     zero     ...      zero  zero   zero     zero   zero
# 1201.2706v2     zero     zero     ...      zero  zero   zero     zero   zero
# 1201.6655v1    baixo     zero     ...      zero  zero   zero    baixo   zero
# 1202.1334v2     zero     zero     ...      zero  zero  baixo    baixo   zero
# 1202.3698v1     zero     zero     ...      zero  zero   alto    baixo  baixo
#
#               york   zero zeros  zhang community_y
# id
# 1201.2250v1   alto  baixo  zero   zero           6
# 1201.2706v2  baixo   zero  zero   zero         116
# 1201.6655v1   zero   zero  zero   zero         151
# 1202.1334v2   zero   zero  zero  baixo         151
# 1202.3698v1   zero   zero  zero   zero         134
#
# [5 rows x 4351 columns]

# %%
x2.to_csv('doc_term_matrix_freq_wo_header_nostem_discrete.csv',header=True,index=False)

# %%
doc_term_matrix.community.value_counts()
# Out:
# 104    98
# 153    95
# 6      87
# 134    68
# 156    56
# 256    41
# 80     41
# 116    35
# 151    29
# 145    18
# Name: community, dtype: int64

# %%
doc_term_matrix.drop('community',axis=1).apply(lambda x: np.corrcoef(x.values,doc_term_matrix.community.values)[0,1])
# Out:
# aaai                             0.014700
# aaai press                       0.018226
# aalborg                          0.342647
# aalborg denmark                  0.319073
# abbrevi                          0.063080
# abduct                          -0.065507
# abil                             0.004500
# abl                             -0.005611
# abov                            -0.006502
# abov equat                      -0.011343
# abov exampl                     -0.048061
# abov result                     -0.047705
# absenc                           0.048683
# absent                           0.010926
# absolut                          0.014027
# absorb                           0.130748
# abstract paper                   0.033443
# academ                           0.022029
# academ press                     0.029569
# acceler                         -0.020565
# accept                           0.004710
# access                          -0.049000
# accommod                         0.055704
# accomplish                      -0.069367
# accord                          -0.058847
# account                         -0.008644
# accumul                          0.050655
# accur                           -0.037201
# accuraci                         0.028723
# achiev                          -0.061003
#                                    ...
# wit                             -0.072183
# word                            -0.017061
# work focus                      -0.048310
# work paper                      -0.012657
# work present                    -0.053689
# work section                    -0.020834
# work support                    -0.101936
# work support nation              0.010802
# work use                        -0.044962
# workshop                         0.060743
# workshop uncertainti             0.095603
# workshop uncertainti artifici    0.107380
# world                           -0.076314
# wors                            -0.055954
# worst                           -0.012379
# worst case                       0.005653
# worst-cas                        0.067819
# worth                           -0.061827
# write                           -0.028868
# written                         -0.003038
# wrong                           -0.021380
# x-axi                            0.038907
# y-axi                            0.013146
# year                             0.023771
# yes                              0.048192
# yield                            0.097639
# york                             0.108289
# zero                             0.024684
# zero probabl                    -0.002632
# zhang                           -0.194849
# Length: 4263, dtype: float64

# %%
from scipy.stats import chi2_contingency
chi2_contingency(pd.crosstab(x2.aaai,x2.community).values)
# Out:
# (61.195164799130595,
#  1.3096659985158831e-06,
#  18,
#  array([[ 64.33098592,  30.31690141,  72.46478873,  25.88028169,
#           50.28169014,  13.30985915,  21.44366197,  70.24647887,
#           41.4084507 ,  30.31690141],
#         [ 17.15492958,   8.08450704,  19.32394366,   6.90140845,
#           13.4084507 ,   3.54929577,   5.71830986,  18.73239437,
#           11.04225352,   8.08450704],
#         [  5.51408451,   2.59859155,   6.21126761,   2.21830986,
#            4.30985915,   1.14084507,   1.83802817,   6.02112676,
#            3.54929577,   2.59859155]]))

# %%
b = x2.drop('community',axis=1).apply(lambda x: chi2_contingency(pd.crosstab(x,x2.community))[1])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-120-e84910908e47> in <module>()
# ----> 1 b = x2.drop('community',axis=1).apply(lambda x: chi2_contingency(pd.crosstab(x,x2.community))[1])
#       2 b.sort_values(ascending=True)
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4852                         f, axis,
#    4853                         reduce=reduce,
# -> 4854                         ignore_failures=ignore_failures)
#    4855             else:
#    4856                 return self._apply_broadcast(f, axis)
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4908                     labels = self._get_agg_axis(axis)
#    4909                     result = lib.reduce(values, func, axis=axis, dummy=dummy,
# -> 4910                                         labels=labels)
#    4911                     return Series(result, index=labels)
#    4912                 except Exception:
#
# pandas/_libs/src/reduce.pyx in pandas._libs.lib.reduce()
#
# pandas/_libs/src/reduce.pyx in pandas._libs.lib.Reducer.get_result()
#
# <ipython-input-120-e84910908e47> in <lambda>(x)
# ----> 1 b = x2.drop('community',axis=1).apply(lambda x: chi2_contingency(pd.crosstab(x,x2.community))[1])
#       2 b.sort_values(ascending=True)
#
# /usr/local/lib/python3.6/site-packages/pandas/core/reshape/pivot.py in crosstab(index, columns, values, rownames, colnames, aggfunc, margins, margins_name, dropna, normalize)
#     464     table = df.pivot_table('__dummy__', index=rownames, columns=colnames,
#     465                            margins=margins, margins_name=margins_name,
# --> 466                            dropna=dropna, **kwargs)
#     467
#     468     # Post-process
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#    4443                            aggfunc=aggfunc, fill_value=fill_value,
#    4444                            margins=margins, dropna=dropna,
# -> 4445                            margins_name=margins_name)
#    4446
#    4447     def stack(self, level=-1, dropna=True):
#
# /usr/local/lib/python3.6/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#      80
#      81     grouped = data.groupby(keys)
# ---> 82     agged = grouped.agg(aggfunc)
#      83
#      84     table = agged
#
# /usr/local/lib/python3.6/site-packages/pandas/core/groupby.py in aggregate(self, arg, *args, **kwargs)
#    4187         versionadded=''))
#    4188     def aggregate(self, arg, *args, **kwargs):
# -> 4189         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    4190
#    4191     agg = aggregate
#
# /usr/local/lib/python3.6/site-packages/pandas/core/groupby.py in aggregate(self, arg, *args, **kwargs)
#    3628             # grouper specific aggregations
#    3629             if self.grouper.nkeys > 1:
# -> 3630                 return self._python_agg_general(arg, *args, **kwargs)
#    3631             else:
#    3632
#
# /usr/local/lib/python3.6/site-packages/pandas/core/groupby.py in _python_agg_general(self, func, *args, **kwargs)
#     851         for name, obj in self._iterate_slices():
#     852             try:
# --> 853                 result, counts = self.grouper.agg_series(obj, f)
#     854                 output[name] = self._try_cast(result, obj, numeric_only=True)
#     855             except TypeError:
#
# /usr/local/lib/python3.6/site-packages/pandas/core/groupby.py in agg_series(self, obj, func)
#    2263     def agg_series(self, obj, func):
#    2264         try:
# -> 2265             return self._aggregate_series_fast(obj, func)
#    2266         except Exception:
#    2267             return self._aggregate_series_pure_python(obj, func)
#
# /usr/local/lib/python3.6/site-packages/pandas/core/groupby.py in _aggregate_series_fast(self, obj, func)
#    2273             raise TypeError('Incompatible index for Cython grouper')
#    2274
# -> 2275         group_index, _, ngroups = self.group_info
#    2276
#    2277         # avoids object / Series creation overhead
#
# pandas/_libs/properties.pyx in pandas._libs.properties.cache_readonly.__get__()
#
# /usr/local/lib/python3.6/site-packages/pandas/core/groupby.py in group_info(self)
#    1949     @cache_readonly
#    1950     def group_info(self):
# -> 1951         comp_ids, obs_group_ids = self._get_compressed_labels()
#    1952
#    1953         ngroups = len(obs_group_ids)
#
# /usr/local/lib/python3.6/site-packages/pandas/core/groupby.py in _get_compressed_labels(self)
#    1965
#    1966     def _get_compressed_labels(self):
# -> 1967         all_labels = [ping.labels for ping in self.groupings]
#    1968         if len(all_labels) > 1:
#    1969             group_index = get_group_index(all_labels, self.shape,
#
# /usr/local/lib/python3.6/site-packages/pandas/core/groupby.py in <listcomp>(.0)
#    1965
#    1966     def _get_compressed_labels(self):
# -> 1967         all_labels = [ping.labels for ping in self.groupings]
#    1968         if len(all_labels) > 1:
#    1969             group_index = get_group_index(all_labels, self.shape,
#
# /usr/local/lib/python3.6/site-packages/pandas/core/groupby.py in labels(self)
#    2656     def labels(self):
#    2657         if self._labels is None:
# -> 2658             self._make_labels()
#    2659         return self._labels
#    2660
#
# /usr/local/lib/python3.6/site-packages/pandas/core/groupby.py in _make_labels(self)
#    2673             else:
#    2674                 labels, uniques = algorithms.factorize(
# -> 2675                     self.grouper, sort=self.sort)
#    2676                 uniques = Index(uniques, name=self.name)
#    2677             self._labels = labels
#
# /usr/local/lib/python3.6/site-packages/pandas/core/algorithms.py in factorize(values, sort, order, na_sentinel, size_hint)
#     477         from pandas.core.sorting import safe_sort
#     478         uniques, labels = safe_sort(uniques, labels, na_sentinel=na_sentinel,
# --> 479                                     assume_unique=True)
#     480
#     481     uniques = _reconstruct_data(uniques, dtype, original)
#
# /usr/local/lib/python3.6/site-packages/pandas/core/sorting.py in safe_sort(values, labels, na_sentinel, assume_unique)
#     473
#     474     reverse_indexer = np.empty(len(sorter), dtype=np.int_)
# --> 475     reverse_indexer.put(sorter, np.arange(len(sorter)))
#     476
#     477     mask = (labels < -len(values)) | (labels >= len(values)) | \
#
# KeyboardInterrupt:

# %%
x2[b.sort_values(ascending=True)[200:500].index.values.tolist()+['community']].to_csv('doc_term_matrix_freq_chisq_discrete.csv',index=False)

# %%
x3 = pd.read_csv('doc_term_matrix_tfidf_discrete.csv')
x3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568 entries, 0 to 567
# Columns: 4264 entries, aaai to community
# dtypes: int64(1), object(4263)
# memory usage: 18.5+ MB

# %%
b3 = x3.drop('community',axis=1).apply(lambda x: chi2_contingency(pd.crosstab(x,x3.community))[1])

# %%
x3[b3.sort_values(ascending=True)[300:1000].index.values.tolist()+['community']].to_csv('doc_term_matrix_tfidf_chisq_discrete.csv',index=False)
